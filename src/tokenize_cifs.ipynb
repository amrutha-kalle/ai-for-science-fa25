# %% [markdown]
# pull cifs from materials project using code from chemeleon
#
# remove duplicates and whatever using code from chemeleon
#
# preprocess cifs using code from crystallm
#
# tokenize cifs using code from crystallm

# %%
import os
import re
import random
from pathlib import Path
import time
import dotenv
import warnings
import datetime

from tqdm import tqdm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from mp_api.client import MPRester
from pymatgen.core import Structure
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from ase.visualize import view

warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[3], line 16
#      13 import seaborn as sns
#      14 import matplotlib.pyplot as plt
# ---> 16 from mp_api.client import MPRester
#      17 from pymatgen.core import Structure
#      18 from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\mp_api\client\__init__.py:7
#       4 import os
#       5 from importlib.metadata import PackageNotFoundError, version
# ----> 7 from .core import MPRestError
#       8 from .mprester import MPRester
#      10 try:
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\mp_api\client\core\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .client import BaseRester, MPRestError
#       4 from .settings import MAPIClientSettings
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\mp_api\client\core\client.py:26
#      24 import requests
#      25 from bson import json_util
# ---> 26 from emmet.core.utils import jsanitize
#      27 from monty.json import MontyDecoder
#      28 from pydantic import BaseModel, create_model
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\emmet\core\utils.py:33
#      30 except ImportError:
#      31     bson = None  # type: ignore
# ---> 33 SETTINGS = EmmetSettings()
#      36 def get_sg(struc, symprec=SETTINGS.SYMPREC) -> int:
#      37     """helper function to get spacegroup with a loose tolerance"""
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pydantic_settings\main.py:194, in BaseSettings.__init__(__pydantic_self__, _case_sensitive, _nested_model_default_partial_update, _env_prefix, _env_file, _env_file_encoding, _env_ignore_empty, _env_nested_delimiter, _env_nested_max_split, _env_parse_none_str, _env_parse_enums, _cli_prog_name, _cli_parse_args, _cli_settings_source, _cli_parse_none_str, _cli_hide_none_type, _cli_avoid_json, _cli_enforce_required, _cli_use_class_docs_for_groups, _cli_exit_on_error, _cli_prefix, _cli_flag_prefix_char, _cli_implicit_flags, _cli_ignore_unknown_args, _cli_kebab_case, _cli_shortcuts, _secrets_dir, **values)
#     164 def __init__(
#     165     __pydantic_self__,
#     166     _case_sensitive: bool | None = None,
#    (...)    192     **values: Any,
#     193 ) -> None:
# --> 194     super().__init__(
#     195         **__pydantic_self__._settings_build_values(
#     196             values,
#     197             _case_sensitive=_case_sensitive,
#     198             _nested_model_default_partial_update=_nested_model_default_partial_update,
#     199             _env_prefix=_env_prefix,
#     200             _env_file=_env_file,
#     201             _env_file_encoding=_env_file_encoding,
#     202             _env_ignore_empty=_env_ignore_empty,
#     203             _env_nested_delimiter=_env_nested_delimiter,
#     204             _env_nested_max_split=_env_nested_max_split,
#     205             _env_parse_none_str=_env_parse_none_str,
#     206             _env_parse_enums=_env_parse_enums,
#     207             _cli_prog_name=_cli_prog_name,
#     208             _cli_parse_args=_cli_parse_args,
#     209             _cli_settings_source=_cli_settings_source,
#     210             _cli_parse_none_str=_cli_parse_none_str,
#     211             _cli_hide_none_type=_cli_hide_none_type,
#     212             _cli_avoid_json=_cli_avoid_json,
#     213             _cli_enforce_required=_cli_enforce_required,
#     214             _cli_use_class_docs_for_groups=_cli_use_class_docs_for_groups,
#     215             _cli_exit_on_error=_cli_exit_on_error,
#     216             _cli_prefix=_cli_prefix,
#     217             _cli_flag_prefix_char=_cli_flag_prefix_char,
#     218             _cli_implicit_flags=_cli_implicit_flags,
#     219             _cli_ignore_unknown_args=_cli_ignore_unknown_args,
#     220             _cli_kebab_case=_cli_kebab_case,
#     221             _cli_shortcuts=_cli_shortcuts,
#     222             _secrets_dir=_secrets_dir,
#     223         )
#     224     )
#
# File c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 23 validation errors for EmmetSettings
# VASP_DEFAULT_INPUT_SETS.GGA Structure Optimization
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPRelaxSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U Structure Optimization
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPRelaxSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.r2SCAN Structure Optimization
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanRelaxSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.SCAN Structure Optimization
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanRelaxSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.PBEsol Structure Optimization
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanRelaxSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.r2SCAN Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.SCAN Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.PBEsol Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.HSE06 Static
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPScanStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA NSCF Uniform
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNonSCFSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U NSCF Uniform
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNonSCFSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA NSCF Line
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNonSCFSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U NSCF Line
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNonSCFSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA NMR Electric Field Gradient
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNMRSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA NMR Nuclear Shielding
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNMRSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U NMR Electric Field Gradient
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNMRSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U NMR Nuclear Shielding
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPNMRSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA Deformation
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U Deformation
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA DFPT Dielectric
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]
# VASP_DEFAULT_INPUT_SETS.GGA+U DFPT Dielectric
#   Invalid python path: cannot import name 'get_el_sp' from 'pymatgen.core' (c:\Users\amrut\anaconda3\envs\crystalml\Lib\site-packages\pymatgen\core\__init__.py) [type=import_error, input_value='pymatgen.io.vasp.sets.MPStaticSet', input_type=str]

# %%
dotenv.load_dotenv()
MP_API_KEY = os.getenv("MP_API_KEY")
